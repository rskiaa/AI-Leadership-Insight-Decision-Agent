# %% [markdown]
# # AI Leadership Insight Agent Demo
#
# This notebook shows a lightweight end-to-end usage flow for the leadership insight pipeline.

# %% [markdown]
# ## Setup
#
# Make sure you have:
# - installed the dependencies from `requirements.txt`
# - added `GEMINI_API_KEY` to `.env`
# - run `python3 app/ingest.py` to build the FAISS index

# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(repo_root / 'app'))

from pipeline import generate_answer

# %%
queries = [
    'What is our current revenue trend?',
    'Which departments are underperforming?',
    'What were the key risks highlighted in the last quarter?'
]

for query in queries:
    print(f'\nQUERY: {query}\n')
    print(generate_answer(query))
    print('\n' + '=' * 80 + '\n')
